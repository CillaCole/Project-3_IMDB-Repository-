# %% [markdown]
# # Project Database - Part 2
# - Priscilla Cole
# - 11/18/2022

# %%
# library imports
import numpy as np
import pandas as pd
import os, time, json
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

# %%
# inspect data folder
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title.ratings.tsv',
#  'title.akas.tsv',
#  'title_basics.csv.gz',
#  'title.basics.tsv',
#  'title_akas.csv.gz',
#  'title_ratings.csv.gz']

# %%
# load in API creds
with open ('/Users/priscillacole/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
# API key assign
tmdb.API_KEY = login['api-key']

# %%
# define a function for movie certification
def get_movie_with_rating(movie_id):
    movie_id = tmdb.Movies('imdb_id')
    
# save .info and .releases dicts
    info = movie.info()
    releases = movie.releases()

# Loop through countries in releases
    for c in releases['countries']:
        if c['iso_3166_1'] == 'US':
        # Save a "certificatio" key in the info dictionary 
            info['certification'] = c['certification']
    return info

# %%
# Define function to write new .json files

def write_json(new_data, filename): 
     #Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/
    
    with open(filename, 'r+') as file:
        
        # First we load existing data into a dict.
        file_data = json.load(file)
        
        # Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
                
        # Sets file's current position at offset.
        file.seek(0)
        
        # Convert back to json.
        json.dump(file_data, file)

# %%
# see where the stakeholder requested info is
movie = tmdb.Movies(603)

# %%
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/l4QHerTSbMI7qgvasqxP36pqjN6.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 81.585,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.193,
#  'vote_count': 22353}

# %%
# We know our stakeholder is looking for Revenue, Budget, and certification (rating)
    # Certification is not shown in the above output (we'll come back to it)
print(info['budget'])
print(info['revenue'])

# We will also view the imdb_id, which we will need later
print(info['imdb_id'])
# Out:
# 63000000
# 463517383
# tt0133093

# %%
# We can, using our API readme, search our certification
 # Let's try an example
movie = tmdb.Movies('tt0133093')
response = movie.releases()
response
# Out:
# {'id': 603,
#  'countries': [{'certification': '',
#    'iso_3166_1': 'FI',
#    'primary': False,
#    'release_date': '1999-06-05'},
#   {'certification': '',
#    'iso_3166_1': 'NO',
#    'primary': False,
#    'release_date': '1999-07-07'},
#   {'certification': 'M/12',
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '1999-06-09'},
#   {'certification': 'R',
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '1999-03-24'},
#   {'certification': '',
#    'iso_3166_1': 'TH',
#    'primary': False,
#    'release_date': '2021-09-03'},
#   {'certification': 'R',
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '1999-03-30'},
#   {'certification': '12',
#    'iso_3166_1': 'CZ',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': '15',
#    'iso_3166_1': 'NO',
#    'primary': False,
#    'release_date': '1999-07-09'},
#   {'certification': '15',
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '1999-06-11'},
#   {'certification': 'T',
#    'iso_3166_1': 'IT',
#    'primary': False,
#    'release_date': '1999-05-07'},
#   {'certification': '16',
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '1999-06-17'},
#   {'certification': 'K-16',
#    'iso_3166_1': 'FI',
#    'primary': False,
#    'release_date': '1999-07-09'},
#   {'certification': '12',
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '16',
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '1999-06-17'},
#   {'certification': 'PG-12',
#    'iso_3166_1': 'JP',
#    'primary': False,
#    'release_date': '1999-09-11'},
#   {'certification': '14A',
#    'iso_3166_1': 'CA',
#    'primary': False,
#    'release_date': '1999-03-30'},
#   {'certification': 'U',
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '1999-06-23'},
#   {'certification': 'C',
#    'iso_3166_1': 'BG',
#    'primary': False,
#    'release_date': '1999-09-03'},
#   {'certification': '12',
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '1999-05-15'},
#   {'certification': 'M',
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '1999-04-08'},
#   {'certification': 'K-8 ',
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '1999-08-20'},
#   {'certification': '15',
#    'iso_3166_1': 'DK',
#    'primary': False,
#    'release_date': '1999-05-07'},
#   {'certification': '18',
#    'iso_3166_1': 'ES',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'TR',
#    'primary': False,
#    'release_date': '1999-09-03'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '1999-07-14'},
#   {'certification': '13',
#    'iso_3166_1': 'AR',
#    'primary': False,
#    'release_date': '1999-06-10'},
#   {'certification': 'KT/EA ',
#    'iso_3166_1': 'BE',
#    'primary': False,
#    'release_date': '1999-07-07'},
#   {'certification': '',
#    'iso_3166_1': 'CO',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '',
#    'iso_3166_1': 'EE',
#    'primary': False,
#    'release_date': '1999-07-16'},
#   {'certification': '',
#    'iso_3166_1': 'HR',
#    'primary': False,
#    'release_date': '1999-08-26'},
#   {'certification': '16',
#    'iso_3166_1': 'IS',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'ID',
#    'primary': False,
#    'release_date': '1999-07-03'},
#   {'certification': '15',
#    'iso_3166_1': 'IE',
#    'primary': False,
#    'release_date': '1999-06-11'},
#   {'certification': 'PG',
#    'iso_3166_1': 'IL',
#    'primary': False,
#    'release_date': '1999-06-24'},
#   {'certification': '',
#    'iso_3166_1': 'KW',
#    'primary': False,
#    'release_date': '1999-06-09'},
#   {'certification': '18SG',
#    'iso_3166_1': 'MY',
#    'primary': False,
#    'release_date': '1999-05-06'},
#   {'certification': 'B',
#    'iso_3166_1': 'MX',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': 'M',
#    'iso_3166_1': 'NZ',
#    'primary': False,
#    'release_date': '1999-04-08'},
#   {'certification': '',
#    'iso_3166_1': 'PH',
#    'primary': False,
#    'release_date': '1999-05-26'},
#   {'certification': '',
#    'iso_3166_1': 'PL',
#    'primary': False,
#    'release_date': '1999-08-13'},
#   {'certification': 'M/12',
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'RO',
#    'primary': False,
#    'release_date': '1999-09-10'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '1999-10-14'},
#   {'certification': 'PG',
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '1999-04-22'},
#   {'certification': '',
#    'iso_3166_1': 'SK',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': '',
#    'iso_3166_1': 'SI',
#    'primary': False,
#    'release_date': '1999-08-19'},
#   {'certification': '12',
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '1999-06-18'},
#   {'certification': '12',
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '1999-06-23'},
#   {'certification': 'PG-12',
#    'iso_3166_1': 'TW',
#    'primary': False,
#    'release_date': '1999-06-04'},
#   {'certification': 'G',
#    'iso_3166_1': 'TH',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '',
#    'iso_3166_1': 'UY',
#    'primary': False,
#    'release_date': '1999-07-30'},
#   {'certification': '16',
#    'iso_3166_1': 'UA',
#    'primary': False,
#    'release_date': '2019-07-25'},
#   {'certification': '12',
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '2019-09-25'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2019-10-14'},
#   {'certification': 'IIB',
#    'iso_3166_1': 'HK',
#    'primary': False,
#    'release_date': '1999-05-20'},
#   {'certification': '15',
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-12-03'},
#   {'certification': 'PG13',
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2021-12-02'},
#   {'certification': '',
#    'iso_3166_1': 'CN',
#    'primary': False,
#    'release_date': '2000-01-14'},
#   {'certification': 'U',
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '1999-09-21'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '1999-12-14'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2008-11-26'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2018-05-28'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2004-12-22'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2011-01-12'},
#   {'certification': '12',
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '2008-10-14'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2000-09-12'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2009-01-27'},
#   {'certification': '16',
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '1999-11-25'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2002-09-23'}]}

# %%
# Here is an example
response = movie.releases()
for c in movie.countries:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# R
# R

# %%
# Get the movie object for the current id
movie = tmdb.Movies('tt0133093')

# Save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()

# Loop through countries in releases
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        # Save a "certificatio" key in the info dictionary 
        info['certification'] = c['certification']
        
# *This is adapted into our get_movie_with_rating_funtion at the begining*

# %%
# Do a check, and see that certification has been included in the bottom
# only based on 603 from above
info
# Out:
# {'adult': False,
#  'backdrop_path': '/l4QHerTSbMI7qgvasqxP36pqjN6.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 81.585,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.193,
#  'vote_count': 22353,
#  'certification': 'R'}

# %% [markdown]
# # Movies Released in 2000, 2001

# %%
Years_Filter = [2000, 2002]

# %%
# Load in Title Basics data created and converted in Part 1
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.head()
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In [16], line 2
#       1 # Load in Title Basics data created and converted in Part 1
# ----> 2 basics = pd.read_csv('Data/title_basics.csv.gz')
#       3 basics.head()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/gzip.py:470, in _GzipReader.read(self, size)
#     464 while True:
#     465     if self._decompressor.eof:
#     466         # Ending case: we've come to the end of a member in the file,
#     467         # so finish up this member, and read a new gzip header.
#     468         # Check the CRC and file size, and set the flag so we read
#     469         # a new member
# --> 470         self._read_eof()
#     471         self._new_member = True
#     472         self._decompressor = self._decomp_factory(
#     473             **self._decomp_args)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/gzip.py:516, in _GzipReader._read_eof(self)
#     514 crc32, isize = struct.unpack("<II", self._read_exact(8))
#     515 if crc32 != self._crc:
# --> 516     raise BadGzipFile("CRC check failed %s != %s" % (hex(crc32),
#     517                                                      hex(self._crc)))
#     518 elif isize != (self._stream_size & 0xffffffff):
#     519     raise BadGzipFile("Incorrect length of data produced")
#
# BadGzipFile: CRC check failed 0x36a77f68 != 0xa247119

# %%
# Create a for loop to filter (loop) through years
    # OUTER LOOP
for YEARS in tqdm_notebook(Years_Filter, desc = 'YEARS', position = 0):

# Define the JSON file to store results for year
    # This will show at the beginng 
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEARS}.json'
    
    # Check to see if our file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # Now, create the file if it exists, or leave it if it does exist
    if file_exists == False:
    
        # Save an empty dict to a new json file to append later
        with open(JSON_FILE, 'w') as f:
            json.dump([{'imdb_id':0}],f)
        
    # Now, save our specifisc years as the current df YEAR = 2000
    df_2000 = basics.loc[basics['startYear'] == YEARS].copy()
    df_2000.head()

    # Save movie ids from the year 2000 to a list
    movie_ids = df_2000['tconst'].copy()
    movie_ids

    # Check for any previous data
    previous_df = pd.read_json(JSON_FILE)
    previous_df # Will be empty at first
    
    # Filter out any ids that already exist in our JSON_FILE (helps when returning to our problem later)
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
    
# Get index and movie id from list
    # INNER loop

    for movie_id in tqdm_notebook(movie_ids_to_get,
                                      desc = f'Movies from {YEARS}',
                                      position = 1,
                                      leave = True):
            # Make attempt to retrieve data for movie id
        try:
            temp = get_movie_with_rating(movie_id) # Our first function

                # Extend results of our file with our other function
            write_json(temp, JSON_FILE)

                # Create a short sleep (helps bog down the server less)
            time.sleep(0.02)

            # If it fails, make a dict with just the id
        except Exception as e:
            continue
            
        # Finally, store our info in the JSON_FILE
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER} final_tmdb_data_{YEARS}.csv.gz",
                            compression = 'gzip', index = False)

# %%
final_year_df
